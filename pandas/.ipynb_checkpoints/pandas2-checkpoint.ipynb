# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B611-929B
#
#  Directory of C:\Users\himil\source\repos\python\coursera\MSDataAnalysis\pandas
#
# 06/16/2026  11:45 AM    <DIR>          .
# 06/16/2026  08:24 AM    <DIR>          ..
# 06/16/2026  11:45 AM    <DIR>          .ipynb_checkpoints
# 06/16/2026  08:24 AM               999 data.csv
# 06/16/2026  11:45 AM            28,447 pandas.ipynb
# 06/16/2026  08:24 AM           211,834 Pandas_Cheat_Sheet.pdf
# 06/16/2026  11:45 AM                72 Untitled.ipynb
#                4 File(s)        241,352 bytes
#                3 Dir(s)  99,009,433,600 bytes free

# %%
import pandas as pd
dataframe = pd.read_csv("data.csv")
